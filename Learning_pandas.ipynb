# %% [markdown]
# <a href="https://colab.research.google.com/github/zssgabe/colab_testing/blob/main/Learning_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('data_dictionary.csv')
display(df)
# Out:
#                 Table            Field  \
# 0   Line productivity              NaN
# 1   Line productivity             Date
# 2   Line productivity          Product
# 3   Line productivity            Batch
# 4   Line productivity         Operator
# 5   Line productivity       Start Time
# 6   Line productivity         End Time
# 7            Products              NaN
# 8            Products          Product
# 9            Products           Flavor
# 10           Products             Size
# 11           Products   Min batch time
# 12      Line downtime              NaN
# 13      Line downtime            Batch
# 14      Line downtime  Downtime factor
# 15   Downtime factors              NaN
# 16   Downtime factors           Factor
# 17   Downtime factors      Description
# 18   Downtime factors   Operator Error
#
#                                           Description
# 0   Fact table containing details for each batch p...
# 1                         Date the batch was produced
# ...
